# %%
from datetime import date
date.__dict__
# Out:
# mappingproxy({'__new__': <function date.__new__(*args, **kwargs)>,
#               '__repr__': <slot wrapper '__repr__' of 'datetime.date' objects>,
#               '__hash__': <slot wrapper '__hash__' of 'datetime.date' objects>,
#               '__str__': <slot wrapper '__str__' of 'datetime.date' objects>,
#               '__getattribute__': <slot wrapper '__getattribute__' of 'datetime.date' objects>,
#               '__lt__': <slot wrapper '__lt__' of 'datetime.date' objects>,
#               '__le__': <slot wrapper '__le__' of 'datetime.date' objects>,
#               '__eq__': <slot wrapper '__eq__' of 'datetime.date' objects>,
#               '__ne__': <slot wrapper '__ne__' of 'datetime.date' objects>,
#               '__gt__': <slot wrapper '__gt__' of 'datetime.date' objects>,
#               '__ge__': <slot wrapper '__ge__' of 'datetime.date' objects>,
#               '__add__': <slot wrapper '__add__' of 'datetime.date' objects>,
# ...

# %%
from PIL import Image
Image.__dict__
# Out:
# {'__name__': 'PIL.Image',
#  '__doc__': None,
#  '__package__': 'PIL',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x27bcab2e110>,
#  '__spec__': ModuleSpec(name='PIL.Image', loader=<_frozen_importlib_external.SourceFileLoader object at 0x0000027BCAB2E110>, origin='C:\\Users\\UseR\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\PIL\\Image.py'),
#  '__file__': 'C:\\Users\\UseR\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\PIL\\Image.py',
#  '__cached__': 'C:\\Users\\UseR\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\PIL\\__pycache__\\Image.cpython-310.pyc',
#  '__builtins__': {'__name__': 'builtins',
# ...

# %%
from matplotlib import pyplot
pyplot.__dict__
# Out:
# {'__name__': 'matplotlib.pyplot',
# ...
