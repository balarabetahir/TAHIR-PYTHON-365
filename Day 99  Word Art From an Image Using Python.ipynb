# %%
#reading an Image
from PIL import Image
Image.open("texttoimage.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080>

# %%
import pywhatkit
pywhatkit.image_to_ascii_art('texttoimage.png', 'MyArt')
#reading text file 
read_file = open("MyArt.txt", "r")
print(read_file.read())
# Out:
# &######&@@@@@@@@@@&&###################&%###############&##&#######&##########&&
# SS###SSSSS##########SSSSSSSSSSSS#SSSSSSS$SSSS#SSSSSSSSSSSSSSSSSSSSSSSSS##SSSSSS&
# &@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@$@@@&@@@%&&&&&&&@&&&&&&&&&&&&&&&&&@&&&&&@&&&&&&$
# !..:::......:..:..........::....:!!!!.:.!...::::!:.......:.:::::::::::::::::...:
# !...............:::::::::::::.::::::...:!...::::::::::::::::::::::::::::::::...:
# !.::..........:::::::::::::::.::::::.:::!:::::::::::::::::::::::::::::::::::::::
# :::::::::::::::.:::.::.:::.::::::.::.:::!::::::::::::::::::::::::::::::::...::::
# ::::.:::::.:::::::!:::::::::::::::::::::!::::::::::::::::::::::::::::::::..:::::
# :.::::::::::::::::::::::::::::::::::::.:!:::::::::::::::::::::::::::::::::.:::::
# :.::................................::.:!:::::::::::::::::::::::::::::::::::::::
# :.::........:!!***!!!!*!!*!*!.......::.:!:::::::::::::::::::::::::::::::::::::::
# :.::........:::::::::::::::::.:.....::.:!:::::::::::::::::::::::::::::::::::::::
# ...
