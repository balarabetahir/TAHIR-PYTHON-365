# %%
import matplotlib.pyplot as pyplot
labels = ('Python', 'Java', 'Scala', 'C#')
sizes = [45, 30, 15, 10]
pyplot.pie(sizes,
labels=labels,
autopct='%1, f%%',
counterclock=False,
startangle=105)
#Display the figure
pyplot.show()
#Tahir365
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 4
#       2 labels = ('Python', 'Java', 'Scala', 'C#')
#       3 sizes = [45, 30, 15, 10]
# ----> 4 pyplot.pie(sizes,
#       5 labels=labels,
#       6 autopct='%1, f%%',
#       7 counterclock=False,
#       8 startangle=105)
#       9 #Display the figure
#      10 pyplot.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2715, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2708 @_copy_docstring_and_deprecators(Axes.pie)
#    2709 def pie(
#    2710         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
# ...
